# %%
import pandas as pd
import numpy as np

# %%
actor = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\actor.csv")
cast = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\cast.csv")
director = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\director.csv")
genres = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\genres.csv")
movie = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\movie.csv")
movie_direction = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\movie_direction.csv")
movie_genres = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\movie_genres.csv")
ratings = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\ratings.csv")
reviewer = pd.read_csv(r"D:\Imarticus\PGDA_43\SQL\Datasets\4. Movie Dataset with Questions\reviewer.csv")

# %% [markdown]
# ### i. Write a SQL query to find when the movie 'American Beauty' released. Return movie release year.

# %%
movie[movie.mov_title == 'American Beauty'][['mov_title','mov_year']]
# Out:
#           mov_title  mov_year
# 13  American Beauty      1999

# %% [markdown]
# ### ii. Write a SQL query to find those movies, which were released before 1998. Return movie title.

# %%
movie[movie.mov_year < 1998][['mov_title','mov_year']]
# Out:
#                    mov_title  mov_year
# 0                    Vertigo      1958
# 1              The Innocents      1961
# 2         Lawrence of Arabia      1962
# 3            The Deer Hunter      1978
# 4                    Amadeus      1984
# 5               Blade Runner      1982
# 7         The Usual Suspects      1995
# 8                  Chinatown      1974
# 9              Boogie Nights      1997
# 10                Annie Hall      1977
# 11         Princess Mononoke      1997
# 12  The Shawshank Redemption      1994
# 14                   Titanic      1997
# 15         Good Will Hunting      1997
# 16               Deliverance      1972
# 17             Trainspotting      1996
# 21                    Aliens      1986
# 24             Seven Samurai      1954
# 26        Back to the Future      1985
# 27                Braveheart      1995

# %% [markdown]
# ### iii. Write a query where it should contain all the data of the movies which were released after 1995 and their movie duration was greater than 120.

# %%
movie[(movie.mov_year>1995) & (movie.mov_time>120)]
# Out:
#     mov_id          mov_title  mov_year  mov_time  mov_lang  mov_dt_rel  \
# 6      907     Eyes Wide Shut      1999       159   English         NaN
# 9      910      Boogie Nights      1997       155   English   2/16/1998
# 11     912  Princess Mononoke      1997       134  Japanese  10/19/2001
# 13     914    American Beauty      1999       122   English         NaN
# 14     915            Titanic      1997       194   English   1/23/1998
# 15     916  Good Will Hunting      1997       126   English    6/3/1998
# 18     919       The Prestige      2006       130   English  11/10/2006
# 23     924             Avatar      2009       162   English  12/17/2009
# 25     927      Spirited Away      2001       125  Japanese   9/12/2003
#
#    mov_rel_country
# 6               UK
# 9               UK
# 11              UK
# 13              UK
# 14              UK
# 15              UK
# 18              UK
# 23              UK
# 25              UK

# %% [markdown]
# ### iv. Write a query to determine the Top 7 movies which were released in United Kingdom. Sort the data in ascending order of the movie year.

# %%
movie[movie.mov_rel_country == 'UK'].sort_values(by='mov_year', ascending= True).head(7)
# Out:
#     mov_id           mov_title  mov_year  mov_time mov_lang  mov_dt_rel  \
# 0      901             Vertigo      1958       128  English   8/24/1958
# 2      903  Lawrence of Arabia      1962       216  English  12/11/1962
# 16     917         Deliverance      1972       109  English   10/5/1982
# 8      909           Chinatown      1974       130  English    8/9/1974
# 3      904     The Deer Hunter      1978       183  English    3/8/1979
# 5      906        Blade Runner      1982       117  English    9/9/1982
# 4      905             Amadeus      1984       160  English    1/7/1985
#
#    mov_rel_country
# 0               UK
# 2               UK
# 16              UK
# 8               UK
# 3               UK
# 5               UK
# 4               UK

# %% [markdown]
# ### v. Set the language of movie language as 'Chinese' for the movie which has its existing language as Japanese and the movie year was 2001.

# %%
movie.loc[(movie.mov_lang == 'Japanese') & (movie.mov_year == 2001), 'mov_lang'] = 'Chinese'

# %%
movie[(movie.mov_lang == 'Chinese') & (movie.mov_year == 2001)]
# Out:
#     mov_id      mov_title  mov_year  mov_time mov_lang mov_dt_rel  \
# 25     927  Spirited Away      2001       125  Chinese  9/12/2003
#
#    mov_rel_country
# 25              UK

# %%
movie.tail()
# Out:
#     mov_id           mov_title  mov_year  mov_time  mov_lang  mov_dt_rel  \
# 23     924              Avatar      2009       162   English  12/17/2009
# 24     926       Seven Samurai      1954       207  Japanese   4/26/1954
# 25     927       Spirited Away      2001       125   Chinese   9/12/2003
# 26     928  Back to the Future      1985       116   English   12/4/1985
# 27     925          Braveheart      1995       178   English    9/8/1995
#
#    mov_rel_country
# 23              UK
# 24              JP
# 25              UK
# 26              UK
# 27              UK

# %% [markdown]
# ### vi. Write a SQL query to find name of all the reviewers who rated the movie 'Slumdog Millionaire'.

# %%
movie.head(1)
# Out:
#    mov_id mov_title  mov_year  mov_time mov_lang mov_dt_rel mov_rel_country
# 0     901   Vertigo      1958       128  English  8/24/1958              UK

# %%
reviewer.head(1)
# Out:
#    rev_id     rev_name
# 0    9001  Righty Sock

# %%
ratings.head(1)
# Out:
#    mov_id  rev_id  rev_stars  num_o_ratings
# 0     901    9001        8.4       263575.0

# %%
output = pd.merge(movie,ratings,on='mov_id',how='inner').merge(reviewer,on= 'rev_id',how= 'inner')

# %%
output[output.mov_title == 'Slumdog Millionaire'][['mov_title','rev_name']]
# Out:
#               mov_title        rev_name
# 14  Slumdog Millionaire  Vincent Cadena

# %% [markdown]
# ### vii. Write a query which fetch the first name, last name & role played by the actor where output should all exclude Male actors.

# %%
actor.head(1)
# Out:
#    act_id act_fname act_lname act_gender
# 0     101     James   Stewart          M

# %%
cast.head(1)
# Out:
#    act_id  mov_id                   role
# 0     101     901  John Scottie Ferguson

# %%
actor_cast = pd.merge(actor,cast,on= 'act_id',how= 'inner')

# %%
actor_cast[actor_cast.act_gender != 'M'][['act_fname','act_lname','role']]
# Out:
#     act_fname   act_lname                 role
# 1     Deborah        Kerr         Miss Giddens
# 6      Nicole      Kidman        Alice Harford
# 11     Claire       Danes                  San
# 15       Kate     Winslet  Rose DeWitt Bukater
# 20     Maggie  Gyllenhaal      Elizabeth Darko
# 22  Sigourney      Weaver               Ripley

# %% [markdown]
# ### viii. Write a SQL query to find the actors who played a role in the movie 'Annie Hall'. Fetch all the fields of actor table.

# %%
movie.head(1)
# Out:
#    mov_id mov_title  mov_year  mov_time mov_lang mov_dt_rel mov_rel_country
# 0     901   Vertigo      1958       128  English  8/24/1958              UK

# %%
actor.head(1)
# Out:
#    act_id act_fname act_lname act_gender
# 0     101     James   Stewart          M

# %%
cast.head(1)
# Out:
#    act_id  mov_id                   role
# 0     101     901  John Scottie Ferguson

# %%
result =  pd.merge(movie,cast,on='mov_id',how = 'inner').merge(actor,on='act_id',how= 'inner')

# %%
result[result.mov_title == 'Annie Hall'][['act_id','act_fname','act_lname','act_gender']]
# Out:
#     act_id act_fname act_lname act_gender
# 10     111     Woody     Allen          M

# %% [markdown]
# ### ix. Write a SQL query to find those movies that have been released in countries other than the United Kingdom. Return movie title, movie year, movie time, and date of release, releasing country.

# %%
movie[movie.mov_rel_country != 'UK'][['mov_title','mov_year','mov_time','mov_dt_rel','mov_rel_country']]
# Out:
#         mov_title  mov_year  mov_time mov_dt_rel mov_rel_country
# 1   The Innocents      1961       100  2/19/1962              SW
# 10     Annie Hall      1977        93  4/20/1977             USA
# 24  Seven Samurai      1954       207  4/26/1954              JP

# %% [markdown]
# ### x. Print genre title, maximum movie duration and the count the number of movies in each genre.

# %%
genres.head(1)
# Out:
#    gen_id gen_title
# 0    1001    Action

# %%
movie_genres.head(1)
# Out:
#    mov_id  gen_id
# 0     922    1001

# %%
movie.head(1)
# Out:
#    mov_id mov_title  mov_year  mov_time mov_lang mov_dt_rel mov_rel_country
# 0     901   Vertigo      1958       128  English  8/24/1958              UK

# %%
merge_output = pd.merge(movie,movie_genres,on= 'mov_id',how = 'inner').merge(genres, on= 'gen_id', how = 'inner')

# %%
merge_output.groupby('gen_title').agg(max_duration = ('mov_time','max'),movie_count = ('gen_title','count'))
# Out:
#            max_duration  movie_count
# gen_title
# Action              137            1
# Adventure           216            2
# Animation           134            1
# Comedy               93            1
# Crime               142            2
# Drama               207            4
# Horror              100            1
# Music               118            1
# Mystery             159            3
# Romance             122            1
# Thriller            117            1
# War                 183            1

# %% [markdown]
# ### xi. Create a view which should contain the first name, last name, title of the movie & role played by particular actor.

# %%
actor.head(1)
# Out:
#    act_id act_fname act_lname act_gender
# 0     101     James   Stewart          M

# %%
movie.head(1)
# Out:
#    mov_id mov_title  mov_year  mov_time mov_lang mov_dt_rel mov_rel_country
# 0     901   Vertigo      1958       128  English  8/24/1958              UK

# %%
cast.head(1)
# Out:
#    act_id  mov_id                   role
# 0     101     901  John Scottie Ferguson

# %%
actor_details = pd.merge(movie,cast,on= 'mov_id', how = 'inner').merge(actor,on= 'act_id', how = 'inner')

# %%
view_actor = actor_details[['act_fname','act_lname','mov_title','role']]

# %%
view_actor
# Out:
#     act_fname   act_lname                 mov_title                   role
# 0       James     Stewart                   Vertigo  John Scottie Ferguson
# 1     Deborah        Kerr             The Innocents           Miss Giddens
# 2       Peter      OToole        Lawrence of Arabia          T.E. Lawrence
# 3      Robert     De Niro           The Deer Hunter                Michael
# 4   F. Murray     Abraham                   Amadeus        Antonio Salieri
# 5    Harrison        Ford              Blade Runner           Rick Deckard
# 6      Nicole      Kidman            Eyes Wide Shut          Alice Harford
# 7     Stephen     Baldwin        The Usual Suspects                McManus
# 8        Jack   Nicholson                 Chinatown            J.J. Gittes
# 9        Mark    Wahlberg             Boogie Nights            Eddie Adams
# 10      Woody       Allen                Annie Hall            Alvy Singer
# ...

# %% [markdown]
# ### xii. Write a SQL query to find the movies with the lowest ratings

# %%
movie.head(1)
# Out:
#    mov_id mov_title  mov_year  mov_time mov_lang mov_dt_rel mov_rel_country
# 0     901   Vertigo      1958       128  English  8/24/1958              UK

# %%
ratings.head(1)
# Out:
#    mov_id  rev_id  rev_stars  num_o_ratings
# 0     901    9001        8.4       263575.0

# %%
join_ratings = pd.merge(movie,ratings,on= 'mov_id',how = 'inner')

# %%
join_ratings.num_o_ratings.min()
# Out:
# 13091.0

# %%
join_ratings[join_ratings.num_o_ratings == join_ratings.num_o_ratings.min()][['mov_id','mov_title','num_o_ratings']]
# Out:
#     mov_id       mov_title  num_o_ratings
# 16     923  Beyond the Sea        13091.0
